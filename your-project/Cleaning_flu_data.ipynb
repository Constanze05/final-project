# %%
# import libaries

# import pandas and numpy for data manipulation and exploratory data analysis (set up for complete view on data)
import pandas as pd
pd.set_option('max_columns', 151)
pd.set_option('display.max_rows', None)
import numpy as np

# importing matplotlib and seaborn for visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### FluView Data by state from 2010 to 2019 per week
# Influenza-Like Illness (ILI) Activity Level Indicator

# %%
# when import, try ignore first row

ilinet = pd.read_csv('data/ILINet.csv')
ilinet.head(5)
# Out:
#                                                                                                                                                PERCENTAGE OF VISITS FOR INFLUENZA-LIKE-ILLNESS REPORTED BY SENTINEL PROVIDERS
# REGION TYPE REGION   YEAR WEEK % WEIGHTED ILI %UNWEIGHTED ILI AGE 0-4 AGE 25-49 AGE 25-64 AGE 5-24 AGE 50-64 AGE 65 ILITOTAL NUM. OF PROVIDERS                                     TOTAL PATIENTS
# States      Alabama  2010 40   X              2.13477         X       X         X         X        X         X      249      35                                                             11664
#             Alaska   2010 40   X              0.875146        X       X         X         X        X         X      15       7                                                               1714
# ...

# %% [markdown]
# ### Influenca by state and type from week 40 in 2015 - week 48 in 2019

# %% [raw]
# clinical_labs = pd.read_csv('data/WHO_NREVSS_Clinical_Labs.csv')
# clinical_labs.head(5)

# %%
ilinet.shape
# Out:
# (25669, 1)

# %%
ilinet.reset_index(inplace=True)

# %%
ilinet.head(5)
# Out:
#        level_0   level_1 level_2 level_3         level_4          level_5  \
# 0  REGION TYPE    REGION    YEAR    WEEK  % WEIGHTED ILI  %UNWEIGHTED ILI
# 1       States   Alabama    2010      40               X          2.13477
# 2       States    Alaska    2010      40               X         0.875146
# 3       States   Arizona    2010      40               X         0.674721
# 4       States  Arkansas    2010      40               X         0.696056
#
#    level_6    level_7    level_8   level_9   level_10 level_11  level_12  \
# 0  AGE 0-4  AGE 25-49  AGE 25-64  AGE 5-24  AGE 50-64   AGE 65  ILITOTAL
# 1        X          X          X         X          X        X       249
# 2        X          X          X         X          X        X        15
# 3        X          X          X         X          X        X       172
# 4        X          X          X         X          X        X        18
#
#             level_13  \
# 0  NUM. OF PROVIDERS
# 1                 35
# ...

# %%
ilinet.columns = ilinet.iloc[0]

# %%
ilinet = ilinet.drop(ilinet.index[0])

# %%
ilinet.head(5)
# Out:
# 0 REGION TYPE      REGION  YEAR WEEK % WEIGHTED ILI %UNWEIGHTED ILI AGE 0-4  \
# 1      States     Alabama  2010   40              X         2.13477       X
# 2      States      Alaska  2010   40              X        0.875146       X
# 3      States     Arizona  2010   40              X        0.674721       X
# 4      States    Arkansas  2010   40              X        0.696056       X
# 5      States  California  2010   40              X         1.95412       X
#
# 0 AGE 25-49 AGE 25-64 AGE 5-24 AGE 50-64 AGE 65 ILITOTAL NUM. OF PROVIDERS  \
# 1         X         X        X         X      X      249                35
# 2         X         X        X         X      X       15                 7
# 3         X         X        X         X      X      172                49
# 4         X         X        X         X      X       18                15
# 5         X         X        X         X      X      632               112
#
# 0 TOTAL PATIENTS
# 1          11664
# 2           1714
# ...

# %%
missing_val = ilinet.isnull().sum()
print(missing_val)
# Out:
# 0
# REGION TYPE          0
# REGION               0
# YEAR                 0
# WEEK                 0
# % WEIGHTED ILI       0
# %UNWEIGHTED ILI      0
# AGE 0-4              0
# AGE 25-49            0
# AGE 25-64            0
# AGE 5-24             0
# AGE 50-64            0
# AGE 65               0
# ILITOTAL             0
# NUM. OF PROVIDERS    0
# TOTAL PATIENTS       0
# dtype: int64

# %%
to_drop = ['REGION TYPE','% WEIGHTED ILI','AGE 0-4','AGE 25-49','AGE 25-64','AGE 5-24','AGE 50-64','AGE 65']       
ilinet.drop(columns=to_drop,inplace=True,axis=1)

# %%
ilinet.head(5)
# Out:
# 0                 REGION  YEAR WEEK %UNWEIGHTED ILI ILITOTAL  \
# 1                Alabama  2010   40         2.13477      249
# 2                 Alaska  2010   40        0.875146       15
# 3                Arizona  2010   40        0.674721      172
# 4               Arkansas  2010   40        0.696056       18
# 5             California  2010   40         1.95412      632
# 6               Colorado  2010   40        0.660684      134
# 7            Connecticut  2010   40       0.0783085        3
# 8               Delaware  2010   40        0.100125        4
# 9   District of Columbia  2010   40         2.80877       73
# 10               Florida  2010   40               X        X
# 11               Georgia  2010   40          1.6049      647
# 12                Hawaii  2010   40         1.02934       20
# 13                 Idaho  2010   40        0.414938       19
# 14              Illinois  2010   40         1.28205      505
# ...

# %%
ilinet.tail(5)
# Out:
# 0                                            REGION  YEAR WEEK  \
# 25664                                       Wyoming  2019   49
# 25665  Commonwealth of the Northern Mariana Islands  2019   49
# 25666                                   Puerto Rico  2019   49
# 25667                                Virgin Islands  2019   49
# 25668                                 New York City  2019   49
#
# 0     %UNWEIGHTED ILI ILITOTAL NUM. OF PROVIDERS TOTAL PATIENTS
# 25664         2.24676       59                13           2626
# 25665               X        X                 X              X
# 25666         7.05638      204                 7           2891
# 25667         1.02639        7                 2            682
# 25668         3.43095     3292                68          95950

# %%
ilinet['REGION'].unique()

# %%
ilinet = ilinet.set_index('REGION')

# %%
excl_states = ['New York City', 'Virgin Islands', 'Puerto Rico', 'Commonwealth of the Northern Mariana Islands', 'District of Columbia']

# %%
# states to exclude = ['New York City', 'Virgin Islands', 'Puerto Rico', 'Commonwealth of the Northern Mariana Islands', 'District of Columbia']
ilinet = ilinet[(ilinet.index != 'New York City') | (ilinet.index != 'Virgin Islands') | (ilinet.index != 'Puerto Rico') | (ilinet.index != 'Commonwealth of the Northern Mariana Islands') | (ilinet.index != 'District of Columbia')]

# %%
ilinet.head(5)
# Out:
# 0           YEAR WEEK %UNWEIGHTED ILI ILITOTAL NUM. OF PROVIDERS  \
# REGION
# Alabama     2010   40         2.13477      249                35
# Alaska      2010   40        0.875146       15                 7
# Arizona     2010   40        0.674721      172                49
# Arkansas    2010   40        0.696056       18                15
# California  2010   40         1.95412      632               112
#
# 0          TOTAL PATIENTS
# REGION
# Alabama             11664
# Alaska               1714
# Arizona             25492
# Arkansas             2586
# California          32342

# %%
ilinet.reset_index(level=0, inplace=True)

# %%
ilinet = ilinet.rename(columns = {'REGION': 'STATE'})

# %%
ilinet.head(5)
# Out:
# 0       STATE  YEAR WEEK %UNWEIGHTED ILI ILITOTAL NUM. OF PROVIDERS  \
# 0     Alabama  2010   40         2.13477      249                35
# 1      Alaska  2010   40        0.875146       15                 7
# 2     Arizona  2010   40        0.674721      172                49
# 3    Arkansas  2010   40        0.696056       18                15
# 4  California  2010   40         1.95412      632               112
#
# 0 TOTAL PATIENTS
# 0          11664
# 1           1714
# 2          25492
# 3           2586
# 4          32342

# %% [raw]
# flu_week = ilinet.to_csv('data/flu_week.csv', index=False)
