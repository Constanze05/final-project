# %% [markdown]
# # Weather Data per State week 40 2010 to week 49 2019

# %%
# import libaries

# import pandas and numpy for data manipulation and exploratory data analysis (set up for complete view on data)
import pandas as pd
import numpy as np

# importing matplotlib and seaborn for visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import weather data
alabama = pd.read_csv('data/Alabama.txt')

# %%
alaska = pd.read_csv('data/Alaska.txt')

# %%
# filter data only for Fairbanks Airport
alaska1 = alaska[(alaska['NAME']=='FAIRBANKS INTERNATIONAL AIRPORT, AK US')]

# %%
aac = pd.read_csv('data/Arizona-Arkansas-California.txt')

# %%
ci = pd.read_csv('data/Colorado-Iowa.txt')

# %%
kw = pd.read_csv('data/Kansas-Wyoming.txt')

# %%
# merge data
frames = [alabama, alaska1, aac, ci, kw]
weather = pd.concat(frames, sort=True)

# %%
weather.tail(3)
# Out:
#          AWND        DATE                              NAME  PRCP  SNOW  SNWD  \
# 125612  12.08  2019-12-04  JFK INTERNATIONAL AIRPORT, NY US   0.0   0.0   0.0
# 125613    NaN  2019-12-05  JFK INTERNATIONAL AIRPORT, NY US   0.0   0.0   0.0
# 125614    NaN  2019-12-06  JFK INTERNATIONAL AIRPORT, NY US   NaN   NaN   NaN
#
#             STATION  TAVG  TMAX  TMIN  ...  WT11  WT13  WT14  WT15  WT16  \
# 125612  USW00094789  36.0  39.0  33.0  ...   NaN   NaN   NaN   NaN   NaN
# 125613  USW00094789  40.0  44.0  36.0  ...   NaN   NaN   NaN   NaN   NaN
# 125614  USW00094789  40.0   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
#
#         WT17  WT18  WT19  WT21  WT22
# 125612   NaN   NaN   NaN   NaN   NaN
# 125613   NaN   NaN   NaN   NaN   NaN
# 125614   NaN   NaN   NaN   NaN   NaN
#
# [3 rows x 30 columns]

# %%
weather.shape
# Out:
# (179981, 30)

# %%
missing_val = weather.isnull().sum()
print(missing_val)
# Out:
# AWND         3599
# DATE            0
# NAME            0
# PRCP          191
# SNOW        49738
# SNWD        54196
# STATION         0
# TAVG        95379
# TMAX         3248
# TMIN         3259
# WT01       124510
# WT02       173109
# WT03       163812
# WT04       178927
# WT05       176100
# WT06       179145
# WT07       178758
# WT08       158610
# WT09       178954
# WT10       179942
# WT11       179735
# WT13       166410
# WT14       177592
# WT15       179880
# WT16       163195
# WT17       179850
# WT18       175141
# WT19       179803
# WT21       179611
# WT22       179315
# dtype: int64

# %%
to_drop = ['TAVG','WT01','WT02','WT03','WT04','WT05','WT06','WT07','WT08','WT09','WT10','WT11','WT13','WT14','WT15','WT16','WT17','WT18','WT19','WT21','WT22']       
weather.drop(columns=to_drop,inplace=True,axis=1)

# %%
weather.shape
# Out:
# (179981, 9)

# %%
weather.dtypes
# Out:
# AWND       float64
# DATE        object
# NAME        object
# PRCP       float64
# SNOW       float64
# SNWD       float64
# STATION     object
# TMAX       float64
# TMIN       float64
# dtype: object

# %%
# convert data object to type datetime
weather['DATE'] =  pd.to_datetime(weather['DATE'])

# %%
weather.dtypes
# Out:
# AWND              float64
# DATE       datetime64[ns]
# NAME               object
# PRCP              float64
# SNOW              float64
# SNWD              float64
# STATION            object
# TMAX              float64
# TMIN              float64
# dtype: object

# %%
weather.shape
# Out:
# (179981, 9)

# %%
# 50 states of US
weather['NAME'].nunique()
# Out:
# 50

# %%
# filter data from week 1 in 2010 to week 48 in 2019
weather = weather[(weather['DATE'] > '2010-10-03') & (weather['DATE'] < '2019-12-02')]

# %%
weather.head(5)
# Out:
#      AWND       DATE                       NAME  PRCP  SNOW  SNWD  \
# 276  6.04 2010-10-04  BIRMINGHAM AIRPORT, AL US   0.0   0.0   0.0
# 277  5.37 2010-10-05  BIRMINGHAM AIRPORT, AL US   0.0   0.0   0.0
# 278  3.80 2010-10-06  BIRMINGHAM AIRPORT, AL US   0.0   0.0   0.0
# 279  2.91 2010-10-07  BIRMINGHAM AIRPORT, AL US   0.0   0.0   0.0
# 280  1.12 2010-10-08  BIRMINGHAM AIRPORT, AL US   0.0   0.0   0.0
#
#          STATION  TMAX  TMIN
# 276  USW00013876  69.0  41.0
# 277  USW00013876  73.0  39.0
# 278  USW00013876  78.0  41.0
# 279  USW00013876  86.0  45.0
# 280  USW00013876  89.0  53.0

# %%
weather.tail(5)
# Out:
#          AWND       DATE                              NAME  PRCP  SNOW  SNWD  \
# 125605    NaN 2019-11-27  JFK INTERNATIONAL AIRPORT, NY US  0.01   0.0   0.0
# 125606    NaN 2019-11-28  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 125607    NaN 2019-11-29  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 125608  10.96 2019-11-30  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 125609  14.32 2019-12-01  JFK INTERNATIONAL AIRPORT, NY US  0.59   0.0   0.0
#
#             STATION  TMAX  TMIN
# 125605  USW00094789  56.0  44.0
# 125606  USW00094789  53.0  37.0
# 125607  USW00094789  41.0  30.0
# 125608  USW00094789  44.0  30.0
# 125609  USW00094789  41.0  29.0

# %%
# check if data is complete - from 04.01.2010 to 01.12.2019 = 3619 days * 50 states = 180950 rows expected -> 1349 rows are missing
weather.shape
# Out:
# (166157, 9)

# %%
missing_val = weather.isnull().sum()
print(missing_val)
# Out:
# AWND        3412
# DATE           0
# NAME           0
# PRCP         151
# SNOW       44673
# SNWD       48535
# STATION        0
# TMAX        3130
# TMIN        3141
# dtype: int64

# %%
# all states are still represented
weather['NAME'].nunique()
# Out:
# 50

# %%
# check for unique weather days 
weather['DATE'].nunique()
# Out:
# 3346

# %%
weather.head(5)
# Out:
#      AWND       DATE                       NAME  PRCP  SNOW  SNWD  \
# 276  6.04 2010-10-04  BIRMINGHAM AIRPORT, AL US   0.0   0.0   0.0
# 277  5.37 2010-10-05  BIRMINGHAM AIRPORT, AL US   0.0   0.0   0.0
# 278  3.80 2010-10-06  BIRMINGHAM AIRPORT, AL US   0.0   0.0   0.0
# 279  2.91 2010-10-07  BIRMINGHAM AIRPORT, AL US   0.0   0.0   0.0
# 280  1.12 2010-10-08  BIRMINGHAM AIRPORT, AL US   0.0   0.0   0.0
#
#          STATION  TMAX  TMIN
# 276  USW00013876  69.0  41.0
# 277  USW00013876  73.0  39.0
# 278  USW00013876  78.0  41.0
# 279  USW00013876  86.0  45.0
# 280  USW00013876  89.0  53.0

# %%
weather_week = weather.groupby(['NAME',pd.Grouper(freq='W', key='DATE')]).mean()

# %%
weather_week.reset_index(inplace=True)

# %%
weather_week.head(5)
# Out:
#                                        NAME       DATE      AWND      PRCP  \
# 0  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2010-10-10  6.967143  0.001429
# 1  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2010-10-17  5.208571  0.000000
# 2  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2010-10-24  7.287143  0.024286
# 3  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2010-10-31  8.084286  0.000000
# 4  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2010-11-07  6.070000  0.000000
#
#    SNOW  SNWD       TMAX       TMIN
# 0   0.0   0.0  76.571429  54.142857
# 1   0.0   0.0  74.857143  49.428571
# 2   0.0   0.0  68.285714  47.857143
# 3   0.0   0.0  65.714286  39.714286
# 4   0.0   0.0  67.000000  42.142857

# %%
weather_week['NAME'].nunique()
# Out:
# 50

# %%
stations = pd.read_excel('data/weather_station_dict.xlsx')

# %%
stations_dict = dict(zip(stations['Weather Station'],stations['State']))

# %%
weather_week['STATE'] = weather_week['NAME'].map(stations_dict)

# %%
weather_week.head(60)
# Out:
#                                         NAME       DATE       AWND      PRCP  \
# 0   ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2010-10-10   6.967143  0.001429
# 1   ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2010-10-17   5.208571  0.000000
# 2   ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2010-10-24   7.287143  0.024286
# 3   ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2010-10-31   8.084286  0.000000
# 4   ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2010-11-07   6.070000  0.000000
# 5   ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2010-11-14   6.328571  0.000000
# 6   ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2010-11-21   7.382857  0.000000
# 7   ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2010-11-28   8.884286  0.002857
# 8   ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2010-12-05   4.825714  0.000000
# 9   ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2010-12-12   5.721429  0.000000
# 10  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2010-12-19   6.134286  0.138571
# 11  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2010-12-26   4.730000  0.011429
# 12  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-01-02   7.732857  0.002857
# 13  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-01-09   6.040000  0.000000
# 14  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-01-16   6.454286  0.000000
# 15  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-01-23   8.117143  0.000000
# 16  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-01-30   4.442857  0.000000
# 17  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-02-06  11.601429  0.015714
# 18  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-02-13   6.231429  0.000000
# 19  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-02-20   7.317143  0.000000
# 20  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-02-27   7.702857  0.000000
# 21  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-03-06   6.742857  0.000000
# 22  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-03-13   8.500000  0.000000
# 23  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-03-20   7.541429  0.000000
# 24  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-03-27  10.227143  0.000000
# 25  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-04-03  11.248571  0.000000
# 26  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-04-10  12.878571  0.004286
# 27  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-04-17   9.970000  0.000000
# 28  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-04-24  11.537143  0.000000
# 29  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-05-01  14.700000  0.000000
# 30  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-05-08   6.485714  0.000000
# 31  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-05-15  13.487143  0.000000
# 32  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-05-22   9.875714  0.007143
# 33  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-05-29  12.365714  0.000000
# 34  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-06-05  11.505714  0.000000
# 35  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-06-12   7.061429  0.000000
# 36  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-06-19   9.905714  0.000000
# 37  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-06-26   8.437143  0.000000
# 38  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-07-03   9.781429  0.000000
# 39  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-07-10   6.612857  0.000000
# 40  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-07-17   7.861429  0.000000
# 41  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-07-24   6.932857  0.045714
# 42  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-07-31   8.788571  0.010000
# 43  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-08-07   5.941429  0.017143
# 44  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-08-14   7.285714  0.000000
# 45  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-08-21   8.437143  0.045714
# 46  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-08-28   5.751429  0.054286
# 47  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-09-04   8.371429  0.028571
# 48  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-09-11   9.554286  0.030000
# 49  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-09-18   6.167143  0.014286
# 50  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-09-25   5.625714  0.000000
# 51  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-10-02   7.511429  0.000000
# 52  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-10-09   8.085714  0.205714
# 53  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-10-16   4.475714  0.000000
# 54  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-10-23   5.592857  0.000000
# 55  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-10-30   6.932857  0.005714
# 56  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-11-06   7.637143  0.011429
# 57  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-11-13   6.551429  0.001429
# 58  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2011-11-20   5.975714  0.000000
# 59  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 
# 52  0.000000  0.000000  65.857143  47.142857  New Mexico
# 53  0.000000  0.000000  77.000000  47.142857  New Mexico
# 54  0.000000  0.000000  73.714286  45.714286  New Mexico
# 55  0.000000  0.000000  67.000000  42.000000  New Mexico
# 56  0.000000  0.000000  61.000000  37.000000  New Mexico
# 57  0.000000  0.000000  54.000000  34.142857  New Mexico
# 58  0.000000  0.000000  59.714286  36.857143  New Mexico
# 59  0.000000  0.000000  55.428571  33.571429  New Mexico

# %%
array = weather_week['DATE'].unique()

# %%
#array

# %%
df_from_arr = pd.DataFrame(data=array)

# %%
#df_from_arr

# %%
#df_from_arr.to_excel('data/unique_dates.xlsx', index=False)

# %%
weeks = pd.read_excel('data/unique_dates.xlsx')

# %%
weeks.columns
# Out:
# Index(['DATE', 'WEEK'], dtype='object')

# %%
weeks_dict = dict(zip(weeks['DATE'],weeks['WEEK']))

# %%
weather_week['WEEK'] = weather_week['DATE'].map(weeks_dict)

# %%
year = pd.read_excel('data/unique_year_week.xlsx')

# %%
year.columns
# Out:
# Index(['DATE', 'YEAR'], dtype='object')

# %%
year_dict = dict(zip(year['DATE'],year['YEAR']))

# %%
weather_week['YEAR'] = weather_week['DATE'].map(year_dict)

# %%
weather_week.head(5)
# Out:
#                                        NAME       DATE      AWND      PRCP  \
# 0  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2010-10-10  6.967143  0.001429
# 1  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2010-10-17  5.208571  0.000000
# 2  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2010-10-24  7.287143  0.024286
# 3  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2010-10-31  8.084286  0.000000
# 4  ALBUQUERQUE INTERNATIONAL AIRPORT, NM US 2010-11-07  6.070000  0.000000
#
#    SNOW  SNWD       TMAX       TMIN       STATE  WEEK  YEAR
# 0   0.0   0.0  76.571429  54.142857  New Mexico    40  2010
# 1   0.0   0.0  74.857143  49.428571  New Mexico    41  2010
# 2   0.0   0.0  68.285714  47.857143  New Mexico    42  2010
# 3   0.0   0.0  65.714286  39.714286  New Mexico    43  2010
# 4   0.0   0.0  67.000000  42.142857  New Mexico    44  2010

# %%
weather_week.tail(5)
# Out:
#                                           NAME       DATE      AWND      PRCP  \
# 23752  WILMINGTON NEW CASTLE CO AIRPORT, DE US 2019-11-03  7.924286  0.161429
# 23753  WILMINGTON NEW CASTLE CO AIRPORT, DE US 2019-11-10  6.457143  0.011429
# 23754  WILMINGTON NEW CASTLE CO AIRPORT, DE US 2019-11-17  9.491429  0.012857
# 23755  WILMINGTON NEW CASTLE CO AIRPORT, DE US 2019-11-24  7.120000  0.141429
# 23756  WILMINGTON NEW CASTLE CO AIRPORT, DE US 2019-12-01  7.155000  0.081429
#
#        SNOW  SNWD       TMAX       TMIN     STATE  WEEK  YEAR
# 23752   0.0   0.0  63.000000  44.571429  Delaware    45  2019
# 23753   0.0   0.0  55.000000  32.571429  Delaware    46  2019
# 23754   0.0   0.0  49.714286  27.857143  Delaware    47  2019
# 23755   0.0   0.0  51.571429  35.857143  Delaware    48  2019
# 23756   0.0   0.0  52.428571  33.285714  Delaware    49  2019

# %% [raw]
# weather_week = weather_week.to_csv('data/weather_week.csv', index=False)
